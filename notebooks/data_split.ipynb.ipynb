# %%
from datasets import load_from_disk, DatasetDict
from sklearn.model_selection import train_test_split
import pandas as pd
import os

# %%
DATASET_PATH = "/Users/vishal/Career/Projects/Medical-Q-A-Chatbot/data/processed/medquad_qa_clean"

dataset = load_from_disk(DATASET_PATH)

print(dataset)
# Out:
# Dataset({
#     features: ['question', 'answer'],
#     num_rows: 47441
# })

# %%
df = dataset.to_pandas()

print("Total rows:", len(df))
df.head()
# Out:
# Total rows: 47441
#                                             question  \
# 0       What is (are) keratoderma with woolly hair ?
# 1  How many people are affected by keratoderma wi...
# 2  What are the genetic changes related to kerato...
# 3        Is keratoderma with woolly hair inherited ?
# 4  What are the treatments for keratoderma with w...
#
#                                               answer
# 0  Keratoderma with woolly hair is a group of rel...
# 1  Keratoderma with woolly hair is rare; its prev...
# 2  Mutations in the JUP, DSP, DSC2, and KANK2 gen...
# 3  Most cases of keratoderma with woolly hair hav...
# 4  These resources address the diagnosis or manag...

# %%
df = df.dropna(subset=["question", "answer"]).copy()

df["question"] = df["question"].astype(str).str.strip()
df["answer"] = df["answer"].astype(str).str.strip()

df = df[(df["question"] != "") & (df["answer"] != "")]

print("After cleaning:", len(df))
# Out:
# After cleaning: 16407

# %%
train_df, temp_df = train_test_split(
    df,
    test_size=0.2,
    random_state=42,
    shuffle=True
)

val_df, test_df = train_test_split(
    temp_df,
    test_size=0.5,
    random_state=42,
    shuffle=True
)

print("Train:", len(train_df))
print("Validation:", len(val_df))
print("Test:", len(test_df))
# Out:
# Train: 13125
# Validation: 1641
# Test: 1641

# %%
OUTPUT_DIR = "/Users/vishal/Career/Projects/Medical-Q-A-Chatbot/data/"

train_path = os.path.join(OUTPUT_DIR, "train.csv")
val_path = os.path.join(OUTPUT_DIR, "validation.csv")
test_path = os.path.join(OUTPUT_DIR, "test.csv")

train_df.to_csv(train_path, index=False)
val_df.to_csv(val_path, index=False)
test_df.to_csv(test_path, index=False)

print("Saved:")
print(train_path)
print(val_path)
print(test_path)
# Out:
# Saved:
# /Users/vishal/Career/Projects/Medical-Q-A-Chatbot/data/train.csv
# /Users/vishal/Career/Projects/Medical-Q-A-Chatbot/data/validation.csv
# /Users/vishal/Career/Projects/Medical-Q-A-Chatbot/data/test.csv

# %%
print(pd.read_csv(train_path).shape)
print(pd.read_csv(val_path).shape)
print(pd.read_csv(test_path).shape)
# Out:
# (13125, 2)
# (1641, 2)
# (1641, 2)
